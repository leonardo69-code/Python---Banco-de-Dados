# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo69-code/Python---Banco-de-Dados/blob/main/Gabarito_ETL_SQL_to_Cloud_Storage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (9.1.0)

# %%
import mysql.connector
import pandas as pd

# %%
host = '34.55.109.168' # endereço do banco externo que eu quero acessar
user = 'root'
password = ''
database = 'loja'

# %%
# !curl ipecho.net/plain
# Out:
# 35.196.51.15

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'show tables;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
# Empty DataFrame
# Columns: [Tables_in_loja]
# Index: []

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
create table Cliente (
  id_cliente INT PRIMARY KEY,
  nome VARCHAR (50),
  endereco VARCHAR (100)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
CREATE TABLE Pedido (
    id_pedido INT PRIMARY KEY,
    id_cliente INT,
    descricao VARCHAR(100),
    FOREIGN KEY (id_cliente) REFERENCES Cliente(id_cliente)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
CREATE TABLE Produto (
    id_produto INT PRIMARY KEY,
    nome VARCHAR(50),
    preco DECIMAL(10, 2)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
CREATE TABLE ItemPedido (
    id_item INT PRIMARY KEY,
    id_pedido INT,
    id_produto INT,
    quantidade INT,
    FOREIGN KEY (id_pedido) REFERENCES Pedido(id_pedido),
    FOREIGN KEY (id_produto) REFERENCES Produto(id_produto)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
CREATE TABLE Categoria (
    id_categoria INT PRIMARY KEY,
    nome VARCHAR(50)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
CREATE TABLE ProdutoCategoria (
    id_produto INT,
    id_categoria INT,
    PRIMARY KEY (id_produto, id_categoria),
    FOREIGN KEY (id_produto) REFERENCES Produto(id_produto),
    FOREIGN KEY (id_categoria) REFERENCES Categoria(id_categoria)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
INSERT INTO Cliente (id_cliente, nome, endereco)
VALUES
    (1, 'Douglas', 'SP'),
    (2, 'Daniela', 'SP'),
    (3, 'Ester', 'MG'),
    (4, 'Maria', 'BA'),
    (5, 'Douglas', 'PE'),
    (6, 'Raimundo', 'CE'),
    (7, 'Jucimara', 'GO'),
    (8, 'Marlene', 'AC'),
    (9, 'Douglas', 'MA'),
    (10, 'Daniela', 'PI'),
    (11, 'Pedro', 'PB'),
    (12, 'Joaquim', 'RS'),
    (13, 'Julio', 'TO'),
    (14, 'Carla', 'DF'),
    (15, 'Bianca', 'PA'),
    (16, 'Sandra', 'SP'),
    (17, 'Celso', 'SP'),
    (18, 'Silvana', 'BA'),
    (19, 'Prof Raquel', 'BA'),
    (20, 'Pedro', 'SP'),
    (21, 'Erick', 'BA'),
    (22, 'Denise', 'DF'),
    (23, 'Diana', 'SP'),
    (24, 'Dagmar', 'DF'),
    (25, 'Deiverson', 'SP');
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
INSERT INTO Pedido (id_pedido, id_cliente, descricao)
VALUES
    (1, '1', 'Caneca'),
    (2, '1', 'Garfo'),
    (3, '2', 'Faca'),
    (4, '5', 'Copo'),
    (5, '19', 'Copo'),
    (6, '19', 'Colher'),
    (7, '15', 'Colher'),
    (8, '8', 'Colher'),
    (9, '2', 'Copo'),
    (10, '19', 'Colher'),
    (11, '6', 'Copo'),
    (12, '11', 'Colher'),
    (13, '10', 'Garfo'),
    (14, '4', 'Garfo'),
    (15, '3', 'Colher'),
    (16, '3', 'Garfo'),
    (17, '2', 'Copo'),
    (18, '17', 'Garfo'),
    (19, '14', 'Caneca'),
    (20, '13', 'Caneca');
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
INSERT INTO Produto (id_produto, nome, preco)
VALUES
    (1, 'Caneca', 15.99),
    (2, 'Garfo', 5.99),
    (3, 'Faca', 7.99),
    (4, 'Colher', 3.99),
    (5, 'Copo', 10.99);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
INSERT INTO ItemPedido (id_item, id_pedido, id_produto, quantidade)
VALUES
    (1, 1, 1, 2),
    (2, 2, 2, 5),
    (3, 3, 3, 7),
    (4, 4, 5, 10),
    (5, 5, 5, 11),
    (6, 6, 4, 30),
    (7, 7, 4, 32),
    (8, 8, 4, 44),
    (9, 9, 5, 13),
    (10, 10, 4, 33),
    (11, 11, 5, 34),
    (12, 12, 4, 32),
    (13, 13, 2, 33),
    (14, 14, 2, 34),
    (15, 15, 4, 27),
    (16, 16, 2, 18),
    (17, 17, 5, 17),
    (18, 18, 2, 33),
    (19, 19, 1, 50),
    (20, 20, 1, 47);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
INSERT INTO Categoria (id_categoria, nome)
VALUES
    (1, 'Comer'),
    (2, 'Beber');
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
INSERT INTO ProdutoCategoria (id_produto, id_categoria)
VALUES
    (1, 2),
    (2, 1),
    (3, 1),
    (4, 1),
    (5, 2);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
#tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
#display(tabelas) # exibindo a tabela pandas
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Cliente;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
cliente = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(cliente) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_cliente         nome endereco
# 0            1      Douglas       SP
# 1            2      Daniela       SP
# 2            3        Ester       MG
# 3            4        Maria       BA
# 4            5      Douglas       PE
# 5            6     Raimundo       CE
# 6            7     Jucimara       GO
# 7            8      Marlene       AC
# 8            9      Douglas       MA
# 9           10      Daniela       PI
# 10          11        Pedro       PB
# 11          12      Joaquim       RS
# 12          13        Julio       TO
# 13          14        Carla       DF
# 14          15       Bianca       PA
# 15          16       Sandra       SP
# 16          17        Celso       SP
# 17          18      Silvana       BA
# 18          19  Prof Raquel       BA
# 19          20        Pedro       SP
# 20          21        Erick       BA
# 21          22       Denise       DF
# 22          23        Diana       SP
# 23          24       Dagmar       DF
# 24          25    Deiverson       SP

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'sonic-charmer-440012-s4'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
cliente.to_csv('cliente.csv',index=False)
destination_blob_name = 'tabelas/cliente.csv'
source_file_name = 'cliente.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Pedido;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
pedido = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(pedido) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_pedido  id_cliente descricao
# 0           1           1    Caneca
# 1           2           1     Garfo
# 2           3           2      Faca
# 3           4           5      Copo
# 4           5          19      Copo
# 5           6          19    Colher
# 6           7          15    Colher
# 7           8           8    Colher
# 8           9           2      Copo
# 9          10          19    Colher
# 10         11           6      Copo
# 11         12          11    Colher
# 12         13          10     Garfo
# 13         14           4     Garfo
# 14         15           3    Colher
# 15         16           3     Garfo
# 16         17           2      Copo
# 17         18          17     Garfo
# 18         19          14    Caneca
# 19         20          13    Caneca

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'sonic-charmer-440012-s4'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
pedido.to_csv('pedido.csv',index=False)
destination_blob_name = 'tabelas/pedido.csv'
source_file_name = 'pedido.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Produto;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
produto = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(produto) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_produto    nome  preco
# 0           1  Caneca  15.99
# 1           2   Garfo   5.99
# 2           3    Faca   7.99
# 3           4  Colher   3.99
# 4           5    Copo  10.99

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'sonic-charmer-440012-s4'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
produto.to_csv('produto.csv',index=False)
destination_blob_name = 'tabelas/produto.csv'
source_file_name = 'produto.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM ItemPedido;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
item_pedido = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(item_pedido) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_item  id_pedido  id_produto  quantidade
# 0         1          1           1           2
# 1         2          2           2           5
# 2         3          3           3           7
# 3         4          4           5          10
# 4         5          5           5          11
# 5         6          6           4          30
# 6         7          7           4          32
# 7         8          8           4          44
# 8         9          9           5          13
# 9        10         10           4          33
# 10       11         11           5          34
# 11       12         12           4          32
# 12       13         13           2          33
# 13       14         14           2          34
# 14       15         15           4          27
# 15       16         16           2          18
# 16       17         17           5          17
# 17       18         18           2          33
# 18       19         19           1          50
# 19       20         20           1          47

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'sonic-charmer-440012-s4'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
item_pedido.to_csv('item_pedido.csv',index=False)
destination_blob_name = 'tabelas/item_pedido.csv'
source_file_name = 'item_pedido.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Categoria;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
categoria = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(categoria) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_categoria   nome
# 0             1  Comer
# 1             2  Beber

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'sonic-charmer-440012-s4'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
categoria.to_csv('categoria.csv',index=False)
destination_blob_name = 'tabelas/categoria.csv'
source_file_name = 'categoria.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM ProdutoCategoria;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
produto_categoria = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(produto_categoria) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_produto  id_categoria
# 0           2             1
# 1           3             1
# 2           4             1
# 3           1             2
# 4           5             2

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'sonic-charmer-440012-s4'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
produto_categoria.to_csv('produto_categoria.csv',index=False)
destination_blob_name = 'tabelas/produto_categoria.csv'
source_file_name = 'produto_categoria.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# Updated property [core/project].

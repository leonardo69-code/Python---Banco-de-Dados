# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo69-code/Python---Banco-de-Dados/blob/main/Atividade_Medidas_Estatisticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# importando uma tabela a partir de um link da internet
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSU9iI1TDNfDVCbv4FCa9TDhBmgQKsDtrW6n7R6ndyFzDo2Qeq8sJj-RhJnzKuwm5Lx1f8n7r7ig7Vs/pub?gid=0&single=true&output=csv')
display(df)
# Out:
#    matricula      nome     cidade estado    pais  idade departamento  \
# 0          1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1          2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2          3     Luiza     Santos     SP  Brasil     38     Finanças
# 3          4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4          5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5          6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6          7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7          8     Ester    Itapeva     MG  Brasil     29      Compras
# 8          9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9         10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota
# 0      Gerente    25000     Superior     8
# 1  Coordenador    12000     Superior     6
# 2      Gerente    28000          MBA     9
# 3      Diretor    40000     Mestrado     7
# 4     Analista    23000     Superior     5
# 5     Analista    11000     Superior     9
# 6      Gerente    12000          MBA     4
# 7     Analista    10000     Superior     2
# 8     Analista    13000     Superior     1
# 9     Analista    12000          MBA     7

# %%
# Criando um subdataframe com apenas as colunas quantitativas
quant = df[['idade','salario','nota']]
display(quant)
# Out:
#    idade  salario  nota
# 0     35    25000     8
# 1     29    12000     6
# 2     38    28000     9
# 3     36    40000     7
# 4     28    23000     5
# 5     29    11000     9
# 6     30    12000     4
# 7     29    10000     2
# 8     30    13000     1
# 9     40    12000     7

# %%
# Um subdataframe filtrando todos os elementos com ensino superior
superior = df[df['escolaridade'] == 'Superior']
display(superior)
# Out:
#    matricula     nome     cidade estado    pais  idade departamento  \
# 0          1    Lucas    Atibaia     SP  Brasil     35      Compras
# 1          2      Ana  São Paulo     SP  Brasil     29       Vendas
# 4          5   Sandra    Atibaia     SP  Brasil     28     Produção
# 5          6  Douglas   Bragança     SP  Brasil     29     Finanças
# 7          8    Ester    Itapeva     MG  Brasil     29      Compras
# 8          9    Pedro    Extrema     MG  Brasil     30    Marketing
#
#          cargo  salario escolaridade  nota
# 0      Gerente    25000     Superior     8
# 1  Coordenador    12000     Superior     6
# 4     Analista    23000     Superior     5
# 5     Analista    11000     Superior     9
# 7     Analista    10000     Superior     2
# 8     Analista    13000     Superior     1

# %%
# Calculando as correlações entre as variáveis quantitativas
quant.corr()
# Out:
#             idade   salario      nota
# idade    1.000000  0.463321  0.524626
# salario  0.463321  1.000000  0.416241
# nota     0.524626  0.416241  1.000000

# %%
# Verificando o tipo
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   matricula     10 non-null     int64
#  1   nome          10 non-null     object
#  2   cidade        10 non-null     object
#  3   estado        10 non-null     object
#  4   pais          10 non-null     object
#  5   idade         10 non-null     int64
#  6   departamento  10 non-null     object
#  7   cargo         10 non-null     object
#  8   salario       10 non-null     int64
#  9   escolaridade  10 non-null     object
#  10  nota          10 non-null     int64
# dtypes: int64(4), object(7)
# memory usage: 1008.0+ bytes

# %%
# Calculando as principais medidas de estatística descritiva do df
df.describe()
# Out:
#        matricula     idade       salario       nota
# count   10.00000  10.00000     10.000000  10.000000
# mean     5.50000  32.40000  18600.000000   5.800000
# std      3.02765   4.40202  10002.221975   2.780887
# min      1.00000  28.00000  10000.000000   1.000000
# 25%      3.25000  29.00000  12000.000000   4.250000
# 50%      5.50000  30.00000  12500.000000   6.500000
# 75%      7.75000  35.75000  24500.000000   7.750000
# max     10.00000  40.00000  40000.000000   9.000000

# %%
# Mudando o tipo de dado do atributo matricula
df['matricula'] = df['matricula'].astype('str')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   matricula     10 non-null     object
#  1   nome          10 non-null     object
#  2   cidade        10 non-null     object
#  3   estado        10 non-null     object
#  4   pais          10 non-null     object
#  5   idade         10 non-null     int64
#  6   departamento  10 non-null     object
#  7   cargo         10 non-null     object
#  8   salario       10 non-null     int64
#  9   escolaridade  10 non-null     object
#  10  nota          10 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 1008.0+ bytes

# %%
df.describe()
# Out:
#           idade       salario       nota
# count  10.00000     10.000000  10.000000
# mean   32.40000  18600.000000   5.800000
# std     4.40202  10002.221975   2.780887
# min    28.00000  10000.000000   1.000000
# 25%    29.00000  12000.000000   4.250000
# 50%    30.00000  12500.000000   6.500000
# 75%    35.75000  24500.000000   7.750000
# max    40.00000  40000.000000   9.000000

# %%
# Agrupamentos (Groupby)
'''
Em análise de dados os atributos qualitativos são dimensões e os atributos
quantitativos são métricas, essa classificação é importante, pois, em um
agrupamento temos o seguinte conceito:
Agrupamos por dimensão e agregamos por métrica

Ex.: suponhamos que nosso objetivo seja construir uma visão
do salário médio por cargo
'''
salario_medio = df[['cargo','salario']].groupby('cargo').mean()
display(salario_medio)
# Out:
#                   salario
# cargo
# Analista     13800.000000
# Coordenador  12000.000000
# Diretor      40000.000000
# Gerente      21666.666667

# %%
'''
Suponha que você deseja construir uma visão do salário médio
agrupado por departamento e por cargo
'''
wage_dpt_fun = df[['departamento','cargo','salario']].groupby(['departamento','cargo']).mean()
display(wage_dpt_fun)
# Out:
#                           salario
# departamento cargo
# Compras      Analista     10000.0
#              Gerente      25000.0
# Finanças     Analista     11000.0
#              Gerente      28000.0
# Marketing    Analista     13000.0
#              Diretor      40000.0
#              Gerente      12000.0
# Produção     Analista     17500.0
# Vendas       Coordenador  12000.0

# %%
'''
Imagine que você deseja visualizar o total de salário por departamento
'''
total_salario_depto = df[['departamento','salario']].groupby('departamento').sum()
display(total_salario_depto)
# Out:
#               salario
# departamento
# Compras         35000
# Finanças        39000
# Marketing       65000
# Produção        35000
# Vendas          12000

# %%
'''
Qual é o salário médio por departamento
'''
sm_dp = df[['departamento','salario']].groupby('departamento').mean()
display(sm_dp)
# Out:
#                    salario
# departamento
# Compras       17500.000000
# Finanças      19500.000000
# Marketing     21666.666667
# Produção      17500.000000
# Vendas        12000.000000

# %%
# Incluir uma nova coluna com base em uma lista
genero = ['M','F','F','M','F','M','M','F','M','F']
df['genero'] = genero
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2         3     Luiza     Santos     SP  Brasil     38     Finanças
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9        10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota genero
# 0      Gerente    25000     Superior     8      M
# 1  Coordenador    12000     Superior     6      F
# 2      Gerente    28000          MBA     9      F
# 3      Diretor    40000     Mestrado     7      M
# 4     Analista    23000     Superior     5      F
# 5     Analista    11000     Superior     9      M
# 6      Gerente    12000          MBA     4      M
# 7     Analista    10000     Superior     2      F
# 8     Analista    13000     Superior     1      M
# 9     Analista    12000          MBA     7      F

# %%
# Verificando o número de linhas e colunas (nessa ordem) do df
df.shape
# Out:
# (10, 12)

# %%
# Excluindo a coluna genero
df = df.drop(columns='genero')
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2         3     Luiza     Santos     SP  Brasil     38     Finanças
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9        10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota
# 0      Gerente    25000     Superior     8
# 1  Coordenador    12000     Superior     6
# 2      Gerente    28000          MBA     9
# 3      Diretor    40000     Mestrado     7
# 4     Analista    23000     Superior     5
# 5     Analista    11000     Superior     9
# 6      Gerente    12000          MBA     4
# 7     Analista    10000     Superior     2
# 8     Analista    13000     Superior     1
# 9     Analista    12000          MBA     7

# %%
# Incluir uma nova coluna com base em uma lista
genero = ['M','F','F','M','F','M','M','F','M','F']
df['genero'] = genero
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2         3     Luiza     Santos     SP  Brasil     38     Finanças
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9        10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota genero
# 0      Gerente    25000     Superior     8      M
# 1  Coordenador    12000     Superior     6      F
# 2      Gerente    28000          MBA     9      F
# 3      Diretor    40000     Mestrado     7      M
# 4     Analista    23000     Superior     5      F
# 5     Analista    11000     Superior     9      M
# 6      Gerente    12000          MBA     4      M
# 7     Analista    10000     Superior     2      F
# 8     Analista    13000     Superior     1      M
# 9     Analista    12000          MBA     7      F

# %%
'''
Vamos verificar o salário médio por genero
'''
df[['genero','salario']].groupby('genero').mean()
# Out:
#         salario
# genero
# F       17000.0
# M       20200.0

# %%
# Vamos localizar e alterar o salário de fernando

df.loc[3,['salario']] = 12000
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2         3     Luiza     Santos     SP  Brasil     38     Finanças
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9        10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota genero
# 0      Gerente    25000     Superior     8      M
# 1  Coordenador    12000     Superior     6      F
# 2      Gerente    28000          MBA     9      F
# 3      Diretor    12000     Mestrado     7      M
# 4     Analista    23000     Superior     5      F
# 5     Analista    11000     Superior     9      M
# 6      Gerente    12000          MBA     4      M
# 7     Analista    10000     Superior     2      F
# 8     Analista    13000     Superior     1      M
# 9     Analista    12000          MBA     7      F

# %%
'''
Vamos verificar o salário médio por genero
'''
df[['genero','salario']].groupby('genero').mean()
# Out:
#         salario
# genero
# F       17000.0
# M       14600.0

# %%
# Localizar o maior salário do genero M
df[df['genero'] == 'M']['salario'].max()
# Out:
# 25000

# %%
# Inserindo uma nova coluna com base nos valores de outra(s)
'''
Imagine que você precisa criar uma coluna que tenha o valor do fgts depositado
e que esse valor seja (1/12) do salário
'''
df['fgts'] = df['salario'] * (1/12)
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2         3     Luiza     Santos     SP  Brasil     38     Finanças
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9        10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota genero         fgts
# 0      Gerente    25000     Superior     8      M  2083.333333
# 1  Coordenador    12000     Superior     6      F  1000.000000
# 2      Gerente    28000          MBA     9      F  2333.333333
# 3      Diretor    12000     Mestrado     7      M  1000.000000
# 4     Analista    23000     Superior     5      F  1916.666667
# 5     Analista    11000     Superior     9      M   916.666667
# 6      Gerente    12000          MBA     4      M  1000.000000
# 7     Analista    10000     Superior     2      F   833.333333
# 8     Analista    13000     Superior     1      M  1083.333333
# 9     Analista    12000          MBA     7      F  1000.000000

# %%
# Localizar uma interseção de linha com coluna
df.loc[0,['cidade']]
# Out:
# cidade    Atibaia
# Name: 0, dtype: object

# %%
# Inserindo uma nova linha
df.loc[10] = ['11','Zé','Joanópolis','SP','Brasil',41,'Vendas','Analista',11000,'Superior',8,'M',916.6667]
display(df)
# Out:
#    matricula      nome      cidade estado    pais  idade departamento  \
# 0          1     Lucas     Atibaia     SP  Brasil     35      Compras
# 1          2       Ana   São Paulo     SP  Brasil     29       Vendas
# 2          3     Luiza      Santos     SP  Brasil     38     Finanças
# 3          4  Fernando     Atibaia     SP  Brasil     36    Marketing
# 4          5    Sandra     Atibaia     SP  Brasil     28     Produção
# 5          6   Douglas    Bragança     SP  Brasil     29     Finanças
# 6          7   Eduardo     Extrema     MG  Brasil     30    Marketing
# 7          8     Ester     Itapeva     MG  Brasil     29      Compras
# 8          9     Pedro     Extrema     MG  Brasil     30    Marketing
# 9         10     Maria     Extrema     MG  Brasil     40     Produção
# 10        11        Zé  Joanópolis     SP  Brasil     41       Vendas
#
#           cargo  salario escolaridade  nota genero         fgts
# 0       Gerente    25000     Superior     8      M  2083.333333
# 1   Coordenador    12000     Superior     6      F  1000.000000
# 2       Gerente    28000          MBA     9      F  2333.333333
# 3       Diretor    12000     Mestrado     7      M  1000.000000
# 4      Analista    23000     Superior     5      F  1916.666667
# 5      Analista    11000     Superior     9      M   916.666667
# 6       Gerente    12000          MBA     4      M  1000.000000
# 7      Analista    10000     Superior     2      F   833.333333
# 8      Analista    13000     Superior     1      M  1083.333333
# 9      Analista    12000          MBA     7      F  1000.000000
# 10     Analista    11000     Superior     8      M   916.666700

# %%
# Excluindo um linha
df = df.drop(index=10)
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2         3     Luiza     Santos     SP  Brasil     38     Finanças
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9        10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota genero         fgts
# 0      Gerente    25000     Superior     8      M  2083.333333
# 1  Coordenador    12000     Superior     6      F  1000.000000
# 2      Gerente    28000          MBA     9      F  2333.333333
# 3      Diretor    12000     Mestrado     7      M  1000.000000
# 4     Analista    23000     Superior     5      F  1916.666667
# 5     Analista    11000     Superior     9      M   916.666667
# 6      Gerente    12000          MBA     4      M  1000.000000
# 7     Analista    10000     Superior     2      F   833.333333
# 8     Analista    13000     Superior     1      M  1083.333333
# 9     Analista    12000          MBA     7      F  1000.000000

# %%
# Ordenando o df de acordo com um critério
df = df.sort_values(by='salario') # Por padrão essa função ordena de forma crescente
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 9        10     Maria    Extrema     MG  Brasil     40     Produção
# 8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 2         3     Luiza     Santos     SP  Brasil     38     Finanças
#
#          cargo  salario escolaridade  nota genero         fgts
# 7     Analista    10000     Superior     2      F   833.333333
# 5     Analista    11000     Superior     9      M   916.666667
# 1  Coordenador    12000     Superior     6      F  1000.000000
# 3      Diretor    12000     Mestrado     7      M  1000.000000
# 6      Gerente    12000          MBA     4      M  1000.000000
# 9     Analista    12000          MBA     7      F  1000.000000
# 8     Analista    13000     Superior     1      M  1083.333333
# 4     Analista    23000     Superior     5      F  1916.666667
# 0      Gerente    25000     Superior     8      M  2083.333333
# 2      Gerente    28000          MBA     9      F  2333.333333

# %%
# Reorganizar o índice
df = df.reset_index()
display(df)
# Out:
#    index matricula      nome     cidade estado    pais  idade departamento  \
# 0      7         8     Ester    Itapeva     MG  Brasil     29      Compras
# 1      5         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 2      1         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 3      3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4      6         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 5      9        10     Maria    Extrema     MG  Brasil     40     Produção
# 6      8         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 7      4         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 8      0         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 9      2         3     Luiza     Santos     SP  Brasil     38     Finanças
#
#          cargo  salario escolaridade  nota genero         fgts
# 0     Analista    10000     Superior     2      F   833.333333
# 1     Analista    11000     Superior     9      M   916.666667
# 2  Coordenador    12000     Superior     6      F  1000.000000
# 3      Diretor    12000     Mestrado     7      M  1000.000000
# 4      Gerente    12000          MBA     4      M  1000.000000
# 5     Analista    12000          MBA     7      F  1000.000000
# 6     Analista    13000     Superior     1      M  1083.333333
# 7     Analista    23000     Superior     5      F  1916.666667
# 8      Gerente    25000     Superior     8      M  2083.333333
# 9      Gerente    28000          MBA     9      F  2333.333333

# %%
# Excluindo a coluna index gerada no bloco anterior
df = df.drop(columns='index')
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         8     Ester    Itapeva     MG  Brasil     29      Compras
# 1         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 2         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 5        10     Maria    Extrema     MG  Brasil     40     Produção
# 6         9     Pedro    Extrema     MG  Brasil     30    Marketing
# 7         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 8         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 9         3     Luiza     Santos     SP  Brasil     38     Finanças
#
#          cargo  salario escolaridade  nota genero         fgts
# 0     Analista    10000     Superior     2      F   833.333333
# 1     Analista    11000     Superior     9      M   916.666667
# 2  Coordenador    12000     Superior     6      F  1000.000000
# 3      Diretor    12000     Mestrado     7      M  1000.000000
# 4      Gerente    12000          MBA     4      M  1000.000000
# 5     Analista    12000          MBA     7      F  1000.000000
# 6     Analista    13000     Superior     1      M  1083.333333
# 7     Analista    23000     Superior     5      F  1916.666667
# 8      Gerente    25000     Superior     8      M  2083.333333
# 9      Gerente    28000          MBA     9      F  2333.333333

# %%
# Resetando o indice sen gerar nova coluna
df = df.sort_values(by='nota',ascending=False)
display(df)
df = df.reset_index(drop=True)
display(df)
# Out:
#   matricula      nome     cidade estado    pais  idade departamento  \
# 1         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 9         3     Luiza     Santos     SP  Brasil     38     Finanças
# 8         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 5        10     Maria    Extrema     MG  Brasil     40     Produção
# 2         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 7         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 4         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 0         8     Ester    Itapeva     MG  Brasil     29      Compras
# 6         9     Pedro    Extrema     MG  Brasil     30    Marketing
#
#          cargo  salario escolaridade  nota genero         fgts
# 1     Analista    11000     Superior     9      M   916.666667
# 9      Gerente    28000          MBA     9      F  2333.333333
# 8      Gerente    25000     Superior     8      M  2083.333333
# 3      Diretor    12000     Mestrado     7      M  1000.000000
# 5     Analista    12000          MBA     7      F  1000.000000
# 2  Coordenador    12000     Superior     6      F  1000.000000
# 7     Analista    23000     Superior     5      F  1916.666667
# 4      Gerente    12000          MBA     4      M  1000.000000
# 0     Analista    10000     Superior     2      F   833.333333
# 6     Analista    13000     Superior     1      M  1083.333333
#   matricula      nome     cidade estado    pais  idade departamento  \
# 0         6   Douglas   Bragança     SP  Brasil     29     Finanças
# 1         3     Luiza     Santos     SP  Brasil     38     Finanças
# 2         1     Lucas    Atibaia     SP  Brasil     35      Compras
# 3         4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4        10     Maria    Extrema     MG  Brasil     40     Produção
# 5         2       Ana  São Paulo     SP  Brasil     29       Vendas
# 6         5    Sandra    Atibaia     SP  Brasil     28     Produção
# 7         7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 8         8     Ester    Itapeva     MG  Brasil     29      Compras
# 9         9     Pedro    Extrema     MG  Brasil     30    Marketing
#
#          cargo  salario escolaridade  nota genero         fgts
# 0     Analista    11000     Superior     9      M   916.666667
# 1      Gerente    28000          MBA     9      F  2333.333333
# 2      Gerente    25000     Superior     8      M  2083.333333
# 3      Diretor    12000     Mestrado     7      M  1000.000000
# 4     Analista    12000          MBA     7      F  1000.000000
# 5  Coordenador    12000     Superior     6      F  1000.000000
# 6     Analista    23000     Superior     5      F  1916.666667
# 7      Gerente    12000          MBA     4      M  1000.000000
# 8     Analista    10000     Superior     2      F   833.333333
# 9     Analista    13000     Superior     1      M  1083.333333

# %%
# Neste boloco vamos construir uma tabela de frequências para uma variável qualitativa
freq = df['escolaridade'].value_counts()
percentual = df['escolaridade'].value_counts(normalize=True)*100
escolaridades = pd.DataFrame({'freq_abs':freq, 'freq_%':percentual})
escolaridades = escolaridades.sort_values(by='escolaridade') # Frescura
escolaridades = escolaridades.reset_index() # Frescura (Transforma escolaridade de índice para coluna "Frescura")
escolaridades.loc[3] = ['TOTAL', escolaridades['freq_abs'].sum(), escolaridades['freq_%'].sum()]
display(escolaridades)
# Out:
#   escolaridade  freq_abs  freq_%
# 0          MBA         3    30.0
# 1     Mestrado         1    10.0
# 2     Superior         6    60.0
# 3        TOTAL        10   100.0

# %%
escolaridades.shape
# Out:
# (4, 3)

# %%
'''
Crie a tabela de frequências para a variável departamento
'''
# Neste boloco vamos construir uma tabela de frequências para uma variável qualitativa
freq = df['departamento'].value_counts()
percentual = df['departamento'].value_counts(normalize=True)*100
deptos = pd.DataFrame({'freq_abs':freq, 'freq_%':percentual})
deptos = deptos.sort_values(by='departamento') # Frescura
deptos = deptos.reset_index() # Frescura (Transforma escolaridade de índice para coluna "Frescura")
deptos.loc[5] = ['TOTAL', deptos['freq_abs'].sum(), deptos['freq_%'].sum()]
display(deptos)
# Out:
#   departamento  freq_abs  freq_%
# 0      Compras         2    20.0
# 1     Finanças         2    20.0
# 2    Marketing         3    30.0
# 3     Produção         2    20.0
# 4       Vendas         1    10.0
# 5        TOTAL        10   100.0

# %%
# Criando uma tabela de frequências para variável quantitativa
faixas = ['[00 - 02[','[02 - 04[','[04 - 06[','[06 - 08[','[08 - 10]']
df['notas'] = pd.cut(x=df['nota'],bins=[0,1,3,5,7,9],labels=faixas)
freq = df['notas'].value_counts()
percentual = df['notas'].value_counts(normalize=True)*100
notas = pd.DataFrame({'freq_abs':freq, 'freq_%':percentual})
notas = notas.sort_values(by='notas') # Frescura
notas = notas.reset_index() # Frescura (Transforma escolaridade de índice para coluna "Frescura")
notas['freq_acum'] = notas['freq_abs'].cumsum()
notas['freq_acum_%'] = (notas['freq_acum'] / notas['freq_abs'].sum()) * 100
notas.loc[6] = ['TOTAL', notas['freq_abs'].sum(), notas['freq_%'].sum(), '-','-']
display(notas)
# Out:
#        notas  freq_abs  freq_% freq_acum freq_acum_%
# 0  [00 - 02[         1    10.0         1        10.0
# 1  [02 - 04[         1    10.0         2        20.0
# 2  [04 - 06[         2    20.0         4        40.0
# 3  [06 - 08[         3    30.0         7        70.0
# 4  [08 - 10]         3    30.0        10       100.0
# 6      TOTAL        10   100.0         -           -

# %%
'''
Crie a tabela de frequências para idade considerando as faixas:
[25 - 30[,[30 - 35[, [35 - 40]
'''
# Criando uma tabela de frequências para variável quantitativa
faixas = ['[25 - 30[','[30 - 35[', '[35 - 40]']
df['idades'] = pd.cut(x=df['idade'],bins=[25,29,34,40],labels=faixas) # nesta linha devemos colocar um valor antes do limite superior da classe exceto o primeiro e o último
freq = df['idades'].value_counts()
percentual = df['idades'].value_counts(normalize=True)*100
idades = pd.DataFrame({'freq_abs':freq, 'freq_%':percentual})
idades = idades.sort_values(by='idades') # Frescura
idades = idades.reset_index() # Frescura (Transforma escolaridade de índice para coluna "Frescura")
idades['freq_acum'] = idades['freq_abs'].cumsum()
idades['freq_acum_%'] = (idades['freq_acum'] / idades['freq_abs'].sum()) * 100
idades.loc[idades.shape[0]] = ['TOTAL', idades['freq_abs'].sum(), idades['freq_%'].sum(), '-','-']
display(idades)
# Out:
#       idades  freq_abs  freq_% freq_acum freq_acum_%
# 0  [25 - 30[         4    40.0         4        40.0
# 1  [30 - 35[         2    20.0         6        60.0
# 2  [35 - 40]         4    40.0        10       100.0
# 3      TOTAL        10   100.0         -           -

# %% [markdown]
# # Gráficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histograma
df['idade'].hist()
plt.show()

# %%
# Histograma
df['idade'].hist(bins=3)
plt.title('Distribuição das idades dos funcionários')
plt.xlabel('Idade em anos')
plt.ylabel('Quantidade de Funcionários')
plt.show()

# %%
'''
Crie a tabela de frequências para idade considerando as faixas:
[28 - 32[,[32 - 36[, [36 - 40]
'''
# Criando uma tabela de frequências para variável quantitativa
faixas = ['[28 - 32[','[32 - 36[', '[36 - 40]']
df['idades'] = pd.cut(x=df['idade'],bins=[27,31,35,40],labels=faixas) # nesta linha devemos colocar um valor antes do limite superior da classe exceto o primeiro e o último
freq = df['idades'].value_counts()
percentual = df['idades'].value_counts(normalize=True)*100
idades = pd.DataFrame({'freq_abs':freq, 'freq_%':percentual})
idades = idades.sort_values(by='idades') # Frescura
idades = idades.reset_index() # Frescura (Transforma escolaridade de índice para coluna "Frescura")
idades['freq_acum'] = idades['freq_abs'].cumsum()
idades['freq_acum_%'] = (idades['freq_acum'] / idades['freq_abs'].sum()) * 100
idades.loc[idades.shape[0]] = ['TOTAL', idades['freq_abs'].sum(), idades['freq_%'].sum(), '-','-']
display(idades)
# Out:
#       idades  freq_abs  freq_% freq_acum freq_acum_%
# 0  [28 - 32[         6    60.0         6        60.0
# 1  [32 - 36[         1    10.0         7        70.0
# 2  [36 - 40]         3    30.0        10       100.0
# 3      TOTAL        10   100.0         -           -

# %%
# Histograma das notas
df['nota'].hist(bins=4)
plt.title('Distribuição das notas da avaliação de desempenho')
plt.xlabel('Notas')
plt.ylabel('Quantidade de funcionários')
# Out:
# Text(0, 0.5, 'Quantidade de funcionários')

# %%
# Gráfico de barras/colunas
df['notas'].value_counts().plot(kind='bar')
plt.title('Distribuição das notas da avaliação de desempenho')
plt.xlabel('Notas')
plt.ylabel('Quantidade de funcionários')
plt.show()

# %%
# Gráfico de barras/colunas
df['departamento'].value_counts().plot(kind='bar')
plt.title('Distribuição dos funcionários por departamento')
plt.xlabel('Departamento')
plt.ylabel('Quantidade de funcionários')
plt.show()

# %%
# Gráfico do capiroto (pie)
plt.pie(df.groupby('genero')['genero'].count(),
        labels=list((df['genero']).unique()), autopct='%1.2f%%')
plt.show()

# %%
# Gráfico do capiroto (pie)
plt.pie(df.groupby('cidade')['cidade'].count(),
        labels=list((df['cidade']).unique()), autopct='%1.2f%%')
plt.show()

# %%
# Gráfico do capiroto (pie)
plt.pie(df.groupby('departamento')['departamento'].count(),
        labels=list((df['departamento']).unique()), autopct='%1.2f%%')
plt.show()

# %%
# Gráfico do capiroto (pie)
plt.pie(df.groupby('estado')['estado'].count(),
        labels=list((df['estado']).unique()), autopct='%1.2f%%')
plt.show()

# %%
# Diagrama de dispersão (relação entre idade e salario)
sns.scatterplot(x=df['idade'], y=df['salario'], data=df)
plt.show()

# %%
df.shape
# Out:
# (10, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   matricula     10 non-null     object
#  1   nome          10 non-null     object
#  2   cidade        10 non-null     object
#  3   estado        10 non-null     object
#  4   pais          10 non-null     object
#  5   idade         10 non-null     int64
#  6   departamento  10 non-null     object
#  7   cargo         10 non-null     object
#  8   salario       10 non-null     int64
#  9   escolaridade  10 non-null     object
#  10  nota          10 non-null     int64
#  11  genero        10 non-null     object
#  12  fgts          10 non-null     float64
#  13  notas         10 non-null     category
#  14  idades        10 non-null     category
# dtypes: category(2), float64(1), int64(3), object(9)
# memory usage: 1.5+ KB

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo69-code/Python---Banco-de-Dados/blob/main/Gabarito_ETL_B%C3%A1sico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://storage.googleapis.com/etl-basico/dados-brutos/dados_brutos.csv')
display(df)

# %%
# Transformar cada coluna do df em uma lista
nomes = list(df['nome'])
idades = list(df['idade'])
salarios = list(df['salário'])
cargos = list(df['cargo'])
departamentos = list(df['departamento'])

# %%
# Fazendo o tratamento para excluir os registros com nan , erro e Desconhecido
nome = []
idade = []
salario = []
cargo = []
departamento = []
for i in range(len(nomes)):
  if (str(nomes[i]).strip().lower()not in['nan', 'erro', 'desconhecido'] and
      str(idades[i]).strip().lower()not in['nan', 'erro', 'desconhecido'] and
      str(salarios[i]).strip().lower()not in['nan', 'erro', 'desconhecido'] and
      str(cargos[i]).strip().lower()not in['nan', 'erro', 'desconhecido'] and
      str(departamentos[i]).strip().lower()not in['nan','erro','desconhecido']):
    nome.append(nomes[i])
    idade.append(idades[i])
    salario.append(salarios[i])
    cargo.append(cargos[i])
    departamento.append(departamentos[i])

# %%
# Convertendo as listas tratadas em um df pandas

df = pd.DataFrame(zip(nome, idade, salario, cargo, departamento),
                  columns=['nome', 'idade', 'salario', 'cargo', 'departamento'])
display(df)
# Out:
#                nome  idade  salario        cargo departamento
# 0    Carlos Almeida   57.0  6923.55  Coordenador   Financeiro
# 1  Juliana Oliveira   60.0  3618.77     Analista           TI
# 2    Roberto Santos   34.0  6414.65    Consultar       Vendas
# 3    Paulo Oliveira   42.0  5544.54   Assistente       Vendas
# 4   Fernanda Santos   26.0  6500.00    Coordenar           RH
# 5       Maria Souza   37.0  5217.46      Diretor    Marketing

# %%
# Convertendo as listas tratadas em um df pandas
df = pd.DataFrame({
    'nome':nome,
    'idade':idade,
    'salario':salario,
    'cargo':cargo,
    'departamento':departamento
})
display(df)
# Out:
#                nome  idade  salario        cargo departamento
# 0    Carlos Almeida   57.0  6923.55  Coordenador   Financeiro
# 1  Juliana Oliveira   60.0  3618.77     Analista           TI
# 2    Roberto Santos   34.0  6414.65    Consultar       Vendas
# 3    Paulo Oliveira   42.0  5544.54   Assistente       Vendas
# 4   Fernanda Santos   26.0  6500.00    Coordenar           RH
# 5       Maria Souza   37.0  5217.46      Diretor    Marketing

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'turmas-dados'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'etl-basico'
bucket = client.bucket(bucket_name)
df.to_csv('tratados.csv',index=False)
#from google.cloud import storage
destination_blob_name = 'dados-tratados/tratados.csv'
source_file_name = 'tratados.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo69-code/Python---Banco-de-Dados/blob/main/Treinando_Com_Graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# importando uma tabela a partir de um link da internet
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1q64TPaErzCYgXX6Exp1hopq_L2JnRT3j/export?format=csv&gid=1469769408')
display(df)
# Out:
#       Idade Demissão    Viagem de negócios  Diárias recebidas  \
# 0        41      Sim       Viaja raramente               1102
# 1        49      Não  Viaja frequentemente                279
# 2        37      Sim       Viaja raramente               1373
# 3        33      Não  Viaja frequentemente               1392
# 4        27      Não       Viaja raramente                591
# ...     ...      ...                   ...                ...
# 1465     36      Não  Viaja frequentemente                884
# 1466     39      Não       Viaja raramente                613
# 1467     27      Não       Viaja raramente                155
# 1468     49      Não  Viaja frequentemente               1023
# 1469     34      Não       Viaja raramente                628
#
#                     Departamento  Distância de Casa  Escolaridade  \
# 0                         Vendas                  1             2
# 1     Pesquisa e Desenvolvimento                  8             1
# ...

# %%
print(df.columns)
# Out:
# Index(['Idade', 'Demissão', 'Viagem de negócios', 'Diárias recebidas',
#        'Departamento', 'Distância de Casa', 'Escolaridade', 'Área de Formação',
#        'Número de contratos de trabalho na empresa', 'ID Funcionário',
#        'Nível de Satisfação com o ambiente de trabalho', 'Gênero',
#        'Salário por hora', 'Nível de envolvimento com o trabalho',
#        'Nível hierárquico', 'Cargo', 'Satisfação com o trabalho',
#        'Estado civil', 'Renda mensal', 'Salário Mensal',
#        'qtde de empresas que já trabalhou', 'Maior de idade', 'Faz hora extra',
#        'percentual de aumento de salário', 'score de performance',
#        'Satisfação nas relações Não trabalho', 'Jornada padrão de trabalho',
#        'opção de remaunração variável em ações', 'Total de anos trabalhados',
#        'Qtde de treinamentos realizados no último ano',
#        'Equilíbrio vida trabalho', 'Total de anos trabalhados na empresa',
# ...

# %%
# Desvio padrão de idade, renda e distância de casa, separados por gênero
std_por_genero = df.groupby('Gênero')[['Idade', 'Renda mensal', 'Distância de Casa']].std()
print("Desvio padrão por gênero:")
print(std_por_genero)
# Out:
# Desvio padrão por gênero:
#               Idade  Renda mensal  Distância de Casa
# Gênero
# Feminino   9.266083   4695.608507           8.231515
# Masculino  9.042329   4714.856577           8.027361

# %%
# Criando faixas etárias
df['faixa_etaria'] = pd.cut(df['Idade'], bins=[18, 25, 35, 45, 55, 65])

# Calculando estatísticas por faixa etária
estatisticas_por_faixa_etaria = df.groupby('faixa_etaria')[['Renda mensal', 'Total de anos trabalhados']].agg(['mean', 'std', 'min', 'max'])
print("Estatísticas por faixa etária:")
print(estatisticas_por_faixa_etaria)
# Out:
# Estatísticas por faixa etária:
#               Renda mensal                            \
#                       mean          std   min    max
# faixa_etaria
# (18, 25]       3074.069565  1204.170543  1009   8639
# (25, 35]       4895.633663  2756.084254  1052  17444
# (35, 45]       7104.444444  4733.878536  1702  19973
# (45, 55]      10927.960177  5846.731995  2075  19999
# (55, 65]       9197.680851  5878.554725  2066  19943
#
#              Total de anos trabalhados
#                                   mean        std min max
# faixa_etaria
# (18, 25]                      3.347826   2.069170   0   7
# (25, 35]                      7.648515   3.743895   0  17
# (35, 45]                     12.771368   5.860720   1  26
# (45, 55]                     20.424779   8.816959   1  37
# (55, 65]                     20.595745  11.580830   2  40
# ...

# %%
# Média e desvio padrão do salário mensal por gênero e estado civil
salario_genero_estado_civil = df.groupby(['Gênero', 'Estado civil'])['Salário Mensal'].agg(['mean', 'std'])
print("Média e desvio padrão do salário mensal por gênero e estado civil:")
print(salario_genero_estado_civil)
# Out:
# Média e desvio padrão do salário mensal por gênero e estado civil:
#                                 mean          std
# Gênero    Estado civil
# Feminino  Casado        14591.393382  7088.275372
#           Divorciado    14279.709402  7261.466134
#           Solteiro      15020.502513  7033.020299
# Masculino Casado        13673.543641  7128.650397
#           Divorciado    14327.009524  7091.089451
#           Solteiro      14464.332103  7141.448025

# %%
# Desvio padrão do percentual de aumento de salário por faixa etária e gênero
aumento_por_idade_genero = df.groupby(['faixa_etaria', 'Gênero'])['percentual de aumento de salário'].std()
print("Desvio padrão do percentual de aumento de salário por faixa etária e gênero:")
print(aumento_por_idade_genero)
# Out:
# Desvio padrão do percentual de aumento de salário por faixa etária e gênero:
# faixa_etaria  Gênero
# (18, 25]      Feminino     3.625893
#               Masculino    4.016021
# (25, 35]      Feminino     3.756119
#               Masculino    3.625192
# (35, 45]      Feminino     3.504819
#               Masculino    3.614574
# (45, 55]      Feminino     4.002663
#               Masculino    3.467225
# (55, 65]      Feminino     3.876670
#               Masculino    4.059746
# Name: percentual de aumento de salário, dtype: float64
# <ipython-input-7-7c90b2a3879f>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   aumento_por_idade_genero = df.groupby(['faixa_etaria', 'Gênero'])['percentual de aumento de salário'].std()

# %%
# Estatísticas descritivas para funcionários que fazem ou não fazem hora extra
estatisticas_hora_extra = df.groupby('Faz hora extra')[['Idade', 'Renda mensal', 'Distância de Casa']].agg(['mean', 'std', 'min', 'max'])
print("Estatísticas descritivas por status de hora extra:")
print(estatisticas_hora_extra)
# Out:
# Estatísticas descritivas por status de hora extra:
#                     Idade                   Renda mensal                     \
#                      mean       std min max         mean          std   min
# Faz hora extra
# Não             36.762808  8.975894  18  60  6484.926945  4722.875102  1051
# Sim             37.331731  9.526402  18  60  6548.548077  4675.293789  1009
#
#                       Distância de Casa
#                   max              mean       std min max
# Faz hora extra
# Não             19999          9.062619  8.153086   1  29
# Sim             19859          9.521635  7.988818   1  29

# %%
# Estatísticas descritivas gerais para todas as colunas numéricas
estatisticas_gerais = df.describe()
print("Estatísticas gerais:\n", estatisticas_gerais)
# Out:
# Estatísticas gerais:
#               Idade  Diárias recebidas  Distância de Casa  Escolaridade  \
# count  1470.000000        1470.000000        1470.000000   1470.000000
# mean     36.923810         802.485714           9.192517      2.912925
# std       9.135373         403.509100           8.106864      1.024165
# min      18.000000         102.000000           1.000000      1.000000
# 25%      30.000000         465.000000           2.000000      2.000000
# 50%      36.000000         802.000000           7.000000      3.000000
# 75%      43.000000        1157.000000          14.000000      4.000000
# max      60.000000        1499.000000          29.000000      5.000000
#
#        Número de contratos de trabalho na empresa  ID Funcionário  \
# count                                      1470.0     1470.000000
# mean                                          1.0     1024.865306
# std                                           0.0      602.024335
# ...

# %%
# Média
media_idade = df['Idade'].mean()
media_salario = df['Salário Mensal'].mean()
print("Média da Idade:", media_idade)
print("Média do Salário:", media_salario)

# Desvio padrão
desvio_idade = df['Idade'].std()
desvio_salario = df['Salário Mensal'].std()
print("Desvio Padrão da Idade:", desvio_idade)
print("Desvio Padrão do Salário:", desvio_salario)

# Mediana
mediana_idade = df['Idade'].median()
mediana_salario = df['Salário Mensal'].median()
print("Mediana da Idade:", mediana_idade)
print("Mediana do Salário:", mediana_salario)

# Valor mínimo e máximo
min_idade = df['Idade'].min()
max_idade = df['Idade'].max()
print("Idade Mínima:", min_idade)
print("Idade Máxima:", max_idade)
# Out:
# Média da Idade: 36.923809523809524
# Média do Salário: 14313.103401360544
# Desvio Padrão da Idade: 9.135373489136734
# Desvio Padrão do Salário: 7117.786044059973
# Mediana da Idade: 36.0
# Mediana do Salário: 14235.5
# Idade Mínima: 18
# Idade Máxima: 60

# %%
# Estatísticas de salário por gênero
salario_por_genero = df.groupby('Gênero')['Salário Mensal'].agg(['mean', 'std', 'min', 'max'])
print("Estatísticas de Salário por Gênero:\n", salario_por_genero)
# Out:
# Estatísticas de Salário por Gênero:
#                     mean          std   min    max
# Gênero
# Feminino   14674.600340  7097.551706  2094  26997
# Masculino  14072.105442  7125.073278  2097  26999

# %%
# Criando faixas etárias
df['faixa_etaria'] = pd.cut(df['Idade'], bins=[18, 25, 35, 45, 55, 65])

# Estatísticas por faixa etária
estatisticas_por_faixa = df.groupby('faixa_etaria')[['Idade', 'Salário Mensal']].agg(['mean', 'std', 'min', 'max'])
print("Estatísticas por Faixa Etária:\n", estatisticas_por_faixa)
# Out:
# Estatísticas por Faixa Etária:
#                    Idade                   Salário Mensal                     \
#                    mean       std min max           mean          std   min
# faixa_etaria
# (18, 25]      22.713043  1.945599  19  25   14983.713043  7233.137208  2097
# (25, 35]      30.988449  2.799327  26  35   14307.325083  7107.035947  2122
# (35, 45]      39.959402  2.886960  36  45   13590.339744  7112.600826  2094
# (45, 55]      50.123894  2.936764  46  55   15294.305310  6883.769318  2125
# (55, 65]      57.744681  1.374742  56  60   15197.787234  7803.677826  2354
#
#
#                 max
# faixa_etaria
# (18, 25]      26999
# (25, 35]      26997
# (35, 45]      26914
# (45, 55]      26703
# (55, 65]      26236
# ...

# %%
# Estatísticas para quem faz ou não faz hora extra
estatisticas_hora_extra = df.groupby('Faz hora extra')[['Idade', 'Renda mensal', 'Distância de Casa']].agg(['mean', 'std', 'min', 'max'])
print("Estatísticas por Status de Hora Extra:\n", estatisticas_hora_extra)
# Out:
# Estatísticas por Status de Hora Extra:
#                      Idade                   Renda mensal                     \
#                      mean       std min max         mean          std   min
# Faz hora extra
# Não             36.762808  8.975894  18  60  6484.926945  4722.875102  1051
# Sim             37.331731  9.526402  18  60  6548.548077  4675.293789  1009
#
#                       Distância de Casa
#                   max              mean       std min max
# Faz hora extra
# Não             19999          9.062619  8.153086   1  29
# Sim             19859          9.521635  7.988818   1  29

# %%
# Percentis para a Idade e Salário Mensal
percentis_idade = df['Idade'].quantile([0.1, 0.5, 0.9])
percentis_salario = df['Salário Mensal'].quantile([0.1, 0.5, 0.9])
print("Percentis da Idade:\n", percentis_idade)
print("Percentis do Salário Mensal:\n", percentis_salario)
# Out:
# Percentis da Idade:
#  0.1    26.0
# 0.5    36.0
# 0.9    50.0
# Name: Idade, dtype: float64
# Percentis do Salário Mensal:
#  0.1     4603.0
# 0.5    14235.5
# 0.9    24001.7
# Name: Salário Mensal, dtype: float64

# %%
# Média de variáveis importantes agrupadas pelo status de demissão
media_por_demissao = df.groupby('Demissão')[['Idade', 'Total de anos trabalhados',
                                             'Distância de Casa', 'Renda mensal',
                                             'Salário Mensal']].corr()
display(media_por_demissao)
# Out:
#                                        Idade  Total de anos trabalhados  \
# Demissão
# Não      Idade                      1.000000                   0.672753
#          Total de anos trabalhados  0.672753                   1.000000
#          Distância de Casa          0.005828                   0.020947
#          Renda mensal               0.486713                   0.771638
#          Salário Mensal             0.052284                   0.041819
# Sim      Idade                      1.000000                   0.672621
#          Total de anos trabalhados  0.672621                   1.000000
#          Distância de Casa          0.033881                   0.004146
#          Renda mensal               0.500602                   0.742277
#          Salário Mensal            -0.070142                  -0.039143
#
#                                     Distância de Casa  Renda mensal  \
# Demissão
# Não      Idade                               0.005828      0.486713
# ...

# %%
# Média de variáveis importantes agrupadas pelo status de demissão
media_por_demissao = df.groupby('Demissão')[['Idade', 'Total de anos trabalhados',
                                             'Distância de Casa', 'Renda mensal',
                                             'Salário Mensal']].mean()
display(media_por_demissao)
# Out:
#               Idade  Total de anos trabalhados  Distância de Casa  \
# Demissão
# Não       37.561233                  11.862936           8.915653
# Sim       33.607595                   8.244726          10.632911
#
#           Renda mensal  Salário Mensal
# Demissão
# Não        6832.739659    14265.779400
# Sim        4787.092827    14559.308017

# %%
# Criando uma faixa etária
df['faixa_etaria'] = pd.cut(df['Idade'], bins=[18, 25, 35, 45, 55, 65])

# Frequência de demissão por faixa etária
frequencia_faixa_etaria = pd.crosstab(df['faixa_etaria'], df['Demissão'])
print(frequencia_faixa_etaria)

# Criando uma faixa de distância
df['faixa_distancia'] = pd.cut(df['Distância de Casa'], bins=[0, 10, 20, 30, 40, 50])

# Frequência de demissão por faixa de distância
frequencia_faixa_distancia = pd.crosstab(df['faixa_distancia'], df['Demissão'])
print(frequencia_faixa_distancia)
# Out:
# Demissão      Não  Sim
# faixa_etaria
# (18, 25]       75   40
# (25, 35]      490  116
# (35, 45]      425   43
# (45, 55]      200   26
# (55, 65]       39    8
# Demissão         Não  Sim
# faixa_distancia
# (0, 10]          882  144
# (10, 20]         192   48
# (20, 30]         159   45

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograma da idade por status de demissão
sns.histplot(data=df, x='Idade', hue='Demissão', multiple='stack')
plt.title('Distribuição de Idade por Status de Demissão')
plt.show()

# Boxplots para anos trabalhados e distância de casa
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
sns.boxplot(data=df, x='Demissão', y='Total de anos trabalhados', ax=ax[0])
sns.boxplot(data=df, x='Demissão', y='Distância de Casa', ax=ax[1])
plt.suptitle('Boxplots de Anos Trabalhados e Distância de Casa por Status de Demissão')
plt.show()

# %%
df['Demissao_num'] = df['Demissão'].apply(lambda x: 1 if x == 'Sim' else 0)
# Gráfico Boxplot para comparar Idade entre os grupos de demitidos e não demitidos
plt.figure(figsize=(8, 6))
sns.boxplot(x='Demissao_num', y='Idade', data=df)
plt.title('Distribuição de Idade entre Demitidos e Não Demitidos')
plt.xticks([0, 1], ['Não Demitidos', 'Demitidos'])
plt.xlabel('Status de Demissão')
plt.ylabel('Idade')
plt.show()
# Estatísticas descritivas de idade
idade_stats = df.groupby('Demissao_num')['Idade'].describe()
print(idade_stats)
# Out:
#                count       mean      std   min   25%   50%   75%   max
# Demissao_num
# 0             1233.0  37.561233  8.88836  18.0  31.0  36.0  43.0  60.0
# 1              237.0  33.607595  9.68935  18.0  28.0  32.0  39.0  58.0

# %%
# Média de Salário Mensal entre demitidos e não demitidos
salario_media = df.groupby('Demissao_num')['Salário Mensal'].mean()

# Gráfico de barras para comparação de salário
plt.figure(figsize=(8, 6))
salario_media.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Média de Salário Mensal entre Demitidos e Não Demitidos')
plt.xticks([0, 1], ['Não Demitidos', 'Demitidos'], rotation=0)
plt.ylabel('Média de Salário Mensal')
plt.show()

# Estatísticas de Salário Mensal
salario_stats = df.groupby('Demissao_num')['Salário Mensal'].describe()
print(salario_stats)
# Out:
#                count          mean          std     min     25%      50%  \
# Demissao_num
# 0             1233.0  14265.779400  7102.260749  2094.0  7973.0  14120.0
# 1              237.0  14559.308017  7208.153264  2326.0  8870.0  14618.0
#
#                   75%      max
# Demissao_num
# 0             20364.0  26997.0
# 1             21081.0  26999.0

# %%
# Gráfico Boxplot para comparar Distância de Casa entre os grupos
plt.figure(figsize=(8, 6))
sns.boxplot(x='Demissao_num', y='Distância de Casa', data=df)
plt.title('Distribuição de Distância de Casa entre Demitidos e Não Demitidos')
plt.xticks([0, 1], ['Não Demitidos', 'Demitidos'])
plt.xlabel('Status de Demissão')
plt.ylabel('Distância de Casa')
plt.show()

# Estatísticas descritivas de Distância de Casa
distancia_stats = df.groupby('Demissao_num')['Distância de Casa'].describe()
print(distancia_stats)
# Out:
#                count       mean       std  min  25%  50%   75%   max
# Demissao_num
# 0             1233.0   8.915653  8.012633  1.0  2.0  7.0  13.0  29.0
# 1              237.0  10.632911  8.452525  1.0  3.0  9.0  17.0  29.0

# %%
# Gráfico Boxplot para comparar a Satisfação com o Ambiente de Trabalho
plt.figure(figsize=(8, 6))
sns.boxplot(x='Demissao_num', y='Nível de Satisfação com o ambiente de trabalho', data=df)
plt.title('Satisfação com o Ambiente de Trabalho entre Demitidos e Não Demitidos')
plt.xticks([0, 1], ['Não Demitidos', 'Demitidos'])
plt.xlabel('Status de Demissão')
plt.ylabel('Satisfação com o Ambiente de Trabalho')
plt.show()

# Estatísticas descritivas de Satisfação com o Ambiente de Trabalho
satisfacao_ambiente_stats = df.groupby('Demissao_num')['Nível de Satisfação com o ambiente de trabalho'].describe()
print(satisfacao_ambiente_stats)
# Out:
#                count      mean       std  min  25%  50%  75%  max
# Demissao_num
# 0             1233.0  2.771290  1.071132  1.0  2.0  3.0  4.0  4.0
# 1              237.0  2.464135  1.169791  1.0  1.0  3.0  4.0  4.0

# %%
# Gráfico Boxplot para comparar o Score de Performance entre os grupos
plt.figure(figsize=(8, 6))
sns.boxplot(x='Demissao_num', y='score de performance', data=df)
plt.title('Score de Performance entre Demitidos e Não Demitidos')
plt.xticks([0, 1], ['Não Demitidos', 'Demitidos'])
plt.xlabel('Status de Demissão')
plt.ylabel('Score de Performance')
plt.show()

# Estatísticas descritivas de Score de Performance
performance_stats = df.groupby('Demissao_num')['score de performance'].describe()
print(performance_stats)
# Out:
#                count      mean       std  min  25%  50%  75%  max
# Demissao_num
# 0             1233.0  3.153285  0.360408  3.0  3.0  3.0  3.0  4.0
# 1              237.0  3.156118  0.363735  3.0  3.0  3.0  3.0  4.0

# %%
# Gráfico de barras para ver a distribuição de quem faz hora extra entre demitidos e não demitidos
plt.figure(figsize=(8, 6))
sns.countplot(x='Demissao_num', hue='Faz hora extra', data=df)
plt.title('Distribuição de Faz Hora Extra entre Demitidos e Não Demitidos')
plt.xticks([0, 1], ['Não Demitidos', 'Demitidos'])
plt.xlabel('Status de Demissão')
plt.ylabel('Contagem')
plt.legend(title='Faz Hora Extra', labels=['Não', 'Sim'])
plt.show()

# Estatísticas de quem faz hora extra
hora_extra_stats = df.groupby('Demissao_num')['Faz hora extra'].value_counts()
print(hora_extra_stats)
# Out:
# Demissao_num  Faz hora extra
# 0             Não               944
#               Sim               289
# 1             Sim               127
#               Não               110
# Name: count, dtype: int64

# %%
# Gráfico Boxplot para comparar o equilíbrio vida-trabalho entre os grupos
plt.figure(figsize=(8, 6))
sns.boxplot(x='Demissao_num', y='Equilíbrio vida trabalho', data=df)
plt.title('Equilíbrio Vida-Trabalho entre Demitidos e Não Demitidos')
plt.xticks([0, 1], ['Não Demitidos', 'Demitidos'])
plt.xlabel('Status de Demissão')
plt.ylabel('Equilíbrio Vida-Trabalho')
plt.show()

# Estatísticas de Equilíbrio Vida-Trabalho
equilibrio_stats = df.groupby('Demissao_num')['Equilíbrio vida trabalho'].describe()
print(equilibrio_stats)
# Out:
#                count      mean       std  min  25%  50%  75%  max
# Demissao_num
# 0             1233.0  2.781022  0.681907  1.0  2.0  3.0  3.0  4.0
# 1              237.0  2.658228  0.816453  1.0  2.0  3.0  3.0  4.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Selecionando as variáveis de interesse e calculando as médias por grupo
variaveis = ['Idade', 'Distância de Casa', 'Salário Mensal',
             'Nível de Satisfação com o ambiente de trabalho',
             'Nível de envolvimento com o trabalho', 'score de performance',
             'Equilíbrio vida trabalho']

media_por_grupo = df.groupby('Demissao_num')[variaveis].mean()
media_por_grupo = media_por_grupo.rename(index={0: 'Não Demitidos', 1: 'Demitidos'})

# Preparando os dados para o gráfico
valores_demitidos = media_por_grupo.loc['Demitidos'].values
valores_nao_demitidos = media_por_grupo.loc['Não Demitidos'].values

# Adicionando o primeiro valor ao final para fechar o gráfico de radar
valores_demitidos = np.append(valores_demitidos, valores_demitidos[0])
valores_nao_demitidos = np.append(valores_nao_demitidos, valores_nao_demitidos[0])
labels = list(variaveis) + [variaveis[0]]  # Repete o primeiro rótulo para fechar o círculo

# %%
# Corrigindo a lista de rótulos (labels) para ter o mesmo número de itens que angles[:-1]
labels = list(variaveis)  # Sem duplicação do primeiro rótulo

# Número de variáveis
num_variaveis = len(variaveis)

# Configuração do gráfico
angles = [n / float(num_variaveis) * 2 * pi for n in range(num_variaveis)]
angles += angles[:1]  # Adicionando o primeiro ângulo ao final para fechar o gráfico

# Criando o gráfico
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Gráfico para "Não Demitidos"
ax.plot(angles, valores_nao_demitidos, color='b', linewidth=2, linestyle='solid', label='Não Demitidos')
ax.fill(angles, valores_nao_demitidos, color='b', alpha=0.25)

# Gráfico para "Demitidos"
ax.plot(angles, valores_demitidos, color='r', linewidth=2, linestyle='solid', label='Demitidos')
ax.fill(angles, valores_demitidos, color='r', alpha=0.25)

# Adicionando rótulos
plt.xticks(angles[:-1], labels, color='grey', size=10)
ax.set_rlabel_position(30)
plt.yticks(color="grey", size=8)
plt.ylim(0, max(valores_demitidos.max(), valores_nao_demitidos.max()) * 1.1)  # Ajuste da escala

# Título e legenda
plt.title('Comparação entre Demitidos e Não Demitidos em Várias Métricas', size=15, color='black', y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Exibir o gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from math import pi

# Calculando a média das variáveis para cada grupo (demitidos e não demitidos)
variaveis = ['Idade', 'Distância de Casa', 'Salário Mensal',
             'Nível de Satisfação com o ambiente de trabalho',
             'Nível de envolvimento com o trabalho', 'score de performance',
             'Equilíbrio vida trabalho']

media_por_grupo = df.groupby('Demissao_num')[variaveis].mean()
media_por_grupo = media_por_grupo.rename(index={0: 'Não Demitidos', 1: 'Demitidos'})

# Extraindo os valores para cada grupo
valores_demitidos = media_por_grupo.loc['Demitidos'].values
valores_nao_demitidos = media_por_grupo.loc['Não Demitidos'].values

# Adicionando o primeiro valor ao final para fechar o gráfico
valores_demitidos = np.append(valores_demitidos, valores_demitidos[0])
valores_nao_demitidos = np.append(valores_nao_demitidos, valores_nao_demitidos[0])
labels = list(variaveis)  # Mantendo o número exato de labels

# Número de variáveis e ângulos
num_variaveis = len(variaveis)
angles = [n / float(num_variaveis) * 2 * pi for n in range(num_variaveis)]
angles += angles[:1]  # Fechando o gráfico

# Criando o gráfico
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plotando "Não Demitidos"
ax.plot(angles, valores_nao_demitidos, color='b', linewidth=2, linestyle='solid', label='Não Demitidos')
ax.fill(angles, valores_nao_demitidos, color='b', alpha=0.25)

# Plotando "Demitidos" em duas cores (vermelho para "Salário Mensal")
ax.plot(angles, valores_demitidos, color='grey', linewidth=2, linestyle='solid', label='Demitidos')
ax.fill(angles, valores_demitidos, color='grey', alpha=0.15)

# Destaque em vermelho apenas para o Salário Mensal
salario_index = variaveis.index('Salário Mensal')
ax.plot([angles[salario_index], angles[salario_index]],
        [0, valores_demitidos[salario_index]],
        color='red', linewidth=2)

# Adicionando rótulos
plt.xticks(angles[:-1], labels, color='grey', size=10)
ax.set_rlabel_position(30)
plt.yticks(color="grey", size=8)
plt.ylim(0, max(valores_demitidos.max(), valores_nao_demitidos.max()) * 1.1)  # Ajuste da escala

# Título e legenda
plt.title('Comparação entre Demitidos e Não Demitidos (Salário Mensal em destaque)', size=15, color='black', y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Exibir o gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from math import pi

# Calculando a média das variáveis para cada grupo (demitidos e não demitidos)
variaveis = ['Idade', 'Distância de Casa', 'Salário Mensal',
             'Nível de Satisfação com o ambiente de trabalho',
             'Nível de envolvimento com o trabalho', 'score de performance',
             'Equilíbrio vida trabalho']

media_por_grupo = df.groupby('Demissao_num')[variaveis].mean()
media_por_grupo = media_por_grupo.rename(index={0: 'Não Demitidos', 1: 'Demitidos'})

# Extraindo os valores para cada grupo e fechando os dados para o gráfico de radar
valores_demitidos = np.append(media_por_grupo.loc['Demitidos'].values, media_por_grupo.loc['Demitidos'].values[0])
valores_nao_demitidos = np.append(media_por_grupo.loc['Não Demitidos'].values, media_por_grupo.loc['Não Demitidos'].values[0])

# Configuração dos ângulos do gráfico
num_variaveis = len(variaveis)
angles = [n / float(num_variaveis) * 2 * pi for n in range(num_variaveis)]
angles += angles[:1]  # Fechando o gráfico

# Definindo uma paleta de cores (uma cor para cada variável)
cores = ['#FF6347', '#4682B4', '#32CD32', '#FFD700', '#FF69B4', '#8A2BE2', '#20B2AA']

# Criando o gráfico de radar
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plotando cada variável com cores diferentes para "Não Demitidos"
for i, color in enumerate(cores):
    ax.plot([angles[i], angles[i]], [0, valores_nao_demitidos[i]], color=color, linewidth=2, linestyle='solid')
ax.fill(angles, valores_nao_demitidos, color='b', alpha=0.1, label='Não Demitidos')

# Plotando cada variável com cores diferentes para "Demitidos"
for i, color in enumerate(cores):
    ax.plot([angles[i], angles[i]], [0, valores_demitidos[i]], color=color, linewidth=2, linestyle='dashed')
ax.fill(angles, valores_demitidos, color='r', alpha=0.1, label='Demitidos')

# Adicionando rótulos e configurações
plt.xticks(angles[:-1], variaveis, color='grey', size=10)  # Usamos 'variaveis' sem duplicação
ax.set_rlabel_position(30)
plt.yticks(color="grey", size=8)
plt.ylim(0, max(valores_demitidos.max(), valores_nao_demitidos.max()) * 1.1)  # Ajuste da escala

# Título e legenda
plt.title('Comparação entre Demitidos e Não Demitidos em Várias Métricas', size=15, color='black', y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Exibir o gráfico
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo69-code/Python---Banco-de-Dados/blob/main/loja_banco_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Downloading mysql_connector_python-9.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 12.4 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.1.0

# %%
import mysql.connector
import pandas as pd

# %%
host = '34.28.169.219' # endereço do banco externo que eu quero acessar
user = 'root'
password = ''
database = 'loja'

# %%
# !curl ipecho.net/plain
# Out:
# 34.81.163.249

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'show tables;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
tabelas = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(tabelas) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#      Tables_in_loja
# 0         Categoria
# 1           Cliente
# 2        ItemPedido
# 3            Pedido
# 4           Produto
# 5  ProdutoCategoria

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Categoria;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
aluno = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(aluno) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_categoria   nome
# 0             1  Comer
# 1             2  Beber

# %%
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
try:
    # Salvar o DataFrame 'categoria' como um arquivo CSV localmente
    categoria.to_csv('loja_categoria.csv', index=False)

    # Definir o nome do destino no bucket e o caminho do arquivo local
    destination_blob_name = 'banco-loja/loja_categoria.csv'
    source_file_name = 'loja_categoria.csv'

    # Fazer upload do CSV para o bucket do Google Cloud Storage
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file_name)
    print("Arquivo 'loja_categoria.csv' enviado para o Google Cloud Storage com sucesso.")

except NameError:
    print("Erro: o DataFrame 'categoria' não foi definido. Certifique-se de que ele foi carregado corretamente.")
# Out:
# Erro: o DataFrame 'categoria' não foi definido. Certifique-se de que ele foi carregado corretamente.

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Cliente;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
curso = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(curso) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_cliente         nome endereco
# 0            1      Douglas       SP
# 1            2      Daniela       SP
# 2            3        Ester       MG
# 3            4        Maria       BA
# 4            5      Douglas       PE
# 5            6     Raimundo       CE
# 6            7     Jucimara       GO
# 7            8      Marlene       AC
# 8            9      Douglas       MA
# 9           10      Daniela       PI
# 10          11        Pedro       PB
# 11          12      Joaquim       RS
# 12          13        Julio       TO
# 13          14        Carla       DF
# 14          15       Bianca       PA
# 15          16       Sandra       SP
# 16          17        Celso       SP
# 17          18      Silvana       BA
# 18          19  Prof Raquel       BA
# 19          20        Pedro       SP
# 20          21        Erick       BA
# 21          22       Denise       DF
# 22          23        Diana       SP
# 23          24       Dagmar       DF
# 24          25    Deiverson       SP

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'my-first-project'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
curso.to_csv('loja_cliente.csv',index=False)
destination_blob_name = 'banco-loja/loja_cliente.csv'
source_file_name = 'loja_cliente.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# WARNING: [leonardo_state@hotmail.com] does not have permission to access projects instance [my-first-project] (or it may not exist): The caller does not have permission. This command is authenticated as leonardo_state@hotmail.com which is the active account specified by the [core/account] property
# Are you sure you wish to set property [core/project] to my-first-project?
#
# Do you want to continue (Y/n)?  y
#
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM ItemPedido;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
matricula = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(matricula) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_item  id_pedido  id_produto  quantidade
# 0         1          1           1           2
# 1         2          2           2           5
# 2         3          3           3           7
# 3         4          4           5          10
# 4         5          5           5          11
# 5         6          6           4          30
# 6         7          7           4          32
# 7         8          8           4          44
# 8         9          9           5          13
# 9        10         10           4          33
# 10       11         11           5          34
# 11       12         12           4          32
# 12       13         13           2          33
# 13       14         14           2          34
# 14       15         15           4          27
# 15       16         16           2          18
# 16       17         17           5          17
# 17       18         18           2          33
# 18       19         19           1          50
# 19       20         20           1          47

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'my-first-project'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
matricula.to_csv('loja_itempedido.csv',index=False)
destination_blob_name = 'banco-loja/loja_itempedido.csv'
source_file_name = 'loja_itempedido.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# WARNING: [leonardo_state@hotmail.com] does not have permission to access projects instance [my-first-project] (or it may not exist): The caller does not have permission. This command is authenticated as leonardo_state@hotmail.com which is the active account specified by the [core/account] property
# Are you sure you wish to set property [core/project] to my-first-project?
#
# Do you want to continue (Y/n)?  y
#
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Pedido;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
nota = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(nota) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#     id_pedido  id_cliente descricao
# 0           1           1    Caneca
# 1           2           1     Garfo
# 2           3           2      Faca
# 3           4           5      Copo
# 4           5          19      Copo
# 5           6          19    Colher
# 6           7          15    Colher
# 7           8           8    Colher
# 8           9           2      Copo
# 9          10          19    Colher
# 10         11           6      Copo
# 11         12          11    Colher
# 12         13          10     Garfo
# 13         14           4     Garfo
# 14         15           3    Colher
# 15         16           3     Garfo
# 16         17           2      Copo
# 17         18          17     Garfo
# 18         19          14    Caneca
# 19         20          13    Caneca

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'my-first-project'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
nota.to_csv('loja_pedido.csv',index=False)
destination_blob_name = 'banco-loja/loja_pedido.csv'
source_file_name = 'loja_pedido.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# WARNING: [leonardo_state@hotmail.com] does not have permission to access projects instance [my-first-project] (or it may not exist): The caller does not have permission. This command is authenticated as leonardo_state@hotmail.com which is the active account specified by the [core/account] property
# Are you sure you wish to set property [core/project] to my-first-project?
#
# Do you want to continue (Y/n)?  y
#
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM Produto;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
professor = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(professor) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_produto    nome  preco
# 0           1  Caneca  15.99
# 1           2   Garfo   5.99
# 2           3    Faca   7.99
# 3           4  Colher   3.99
# 4           5    Copo  10.99

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'my-first-project'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
nota.to_csv('loja_produto.csv',index=False)
destination_blob_name = 'banco-loja/loja_produto.csv'
source_file_name = 'loja_produto.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# WARNING: [leonardo_state@hotmail.com] does not have permission to access projects instance [my-first-project] (or it may not exist): The caller does not have permission. This command is authenticated as leonardo_state@hotmail.com which is the active account specified by the [core/account] property
# Are you sure you wish to set property [core/project] to my-first-project?
#
# Do you want to continue (Y/n)?  y
#
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = '''
SELECT * FROM ProdutoCategoria;
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
matricula = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(matricula) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    id_produto  id_categoria
# 0           2             1
# 1           3             1
# 2           4             1
# 3           1             2
# 4           5             2

# %%
'''
Fazendo o uploado do arquivo tratado diretamente pelo
Colab, sem passra pela máquina local
'''
from google.colab import auth
auth.authenticate_user()
project_id = 'my-first-project'
# !gcloud config set project {project_id}
from google.cloud import storage
client = storage.Client()
bucket_name = 'projeto-etl-sql'
bucket = client.bucket(bucket_name)
nota.to_csv('loja_produtocategoria.csv',index=False)
destination_blob_name = 'banco-loja/loja_produtocategoria.csv'
source_file_name = 'loja_produtocategoria.csv'
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
# WARNING: [leonardo_state@hotmail.com] does not have permission to access projects instance [my-first-project] (or it may not exist): The caller does not have permission. This command is authenticated as leonardo_state@hotmail.com which is the active account specified by the [core/account] property
# Are you sure you wish to set property [core/project] to my-first-project?
#
# Do you want to continue (Y/n)?  y
#
# Updated property [core/project].
